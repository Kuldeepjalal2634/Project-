# %% [markdown]
# # **Hand Written Digit Prediction - Classification Analysis**
#
# The digits dataset consists of 8x8 pixel images of digits. The images attribute of the dataset stores 8x8 arrays of grayscale values for each
# image. We will use these arrays to visualize the first 4 images. The target attribute of the dataset stores the digit each image represents.

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Import Data**

# %%
from sklearn.datasets import load_digits

# %%
df = load_digits()

# %%
_, axes = plt.subplots(nrows=1, ncols=4, figsize=(19, 6))

for ax, image, label in zip(axes, df.images, df.target):
    ax.set_axis_off()
    ax.imshow(image, cmap=plt.cm.gray_r, interpolation="nearest")
    ax.set_title("Training: %i" % label) # Use %i to format the label as an integer
plt.show()

# %% [markdown]
# # **Data preprocessing**
#
# flatten image![gokL.jpg](data:image/jpeg;base64,...)

# %%
df.images.shape

# %%
df.images[0]

# %%
df.images[0].shape

# %%
len(df.images)

# %%
n_samples = len(df.images)
data = df.images.reshape((n_samples, -1))

# %%
data[0]

# %%
data[0].shape

# %%
data.shape

# %% [markdown]
# # **Scaling Image Data**

# %%
data.min()

# %%
data.max()

# %%
data = data/16

# %%
data.min()

# %%
data.max()

# %%
data[0]

# %% [markdown]
# # **Train Test Split Data**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data, df.target, test_size=0.3)

# %%
X_train. shape, X_test.shape, y_train.shape, y_test. shape
((1257, 68), (540, 64), (1257,), (540,))

# %% [markdown]
# # **Random Forest Model**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train, y_train)

RandomForestClassifier()

# %% [markdown]
# # **Predict Test Data**

# %%
Y_pred = rf.predict(X_test)

# %%
Y_pred

# %% [markdown]
# # **Model Accuracy**

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
confusion_matrix(y_test, Y_pred)

# %%
print(classification_report(y_test, Y_pred))
